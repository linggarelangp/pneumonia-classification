# %% [markdown]
# ## **Notebooks Setup**

# %%
import sys
from pathlib import Path

cwd = Path().resolve()

for parent in [cwd] + list(cwd.parents):
    if (parent / "src").exists():
        ROOT_DIR = parent
        break

sys.path.insert(0, str(ROOT_DIR))

print("ROOT_DIR:", ROOT_DIR)
# Out:
# ROOT_DIR: E:\My Documents\skripsi\model_penelitian

# %% [markdown]
# ## **Import Required Libraries**

# %%
import os
import pandas as pd

from src.data.resize_image import resize_image
from src.config.load_config import load_config
from src.data.build_image_to_csv import build_image_to_csv

config = load_config()

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Data Preparation**

# %%
data_dir = ROOT_DIR / config["paths"]["raw_data"]
output_dir = os.path.join(ROOT_DIR, "data", "splits").replace(os.sep, "/")
namespace_df = "chest_xray_raw"

build_image_to_csv(data_dir, output_dir, namespace_df)
# Out:
# [INFO] Starting process from: E:\My Documents\skripsi\model_penelitian\data\raw\chest_xray_raw
# Processing Normal: 100%|██████████| 10671/10671 [02:33<00:00, 69.63img/s]
# Processing Pneumonia: 100%|██████████| 10097/10097 [01:55<00:00, 87.60img/s]
# [SUCCESS] CSV successfully saved at: E:\My Documents\skripsi\model_penelitian\data\splits\chest_xray_raw.csv
# [INFO] Total Images: 20768
# [INFO] Class Distribution:
# label
# Normal       10671
# Pneumonia    10097
# Name: count, dtype: int64

# %%
df_path = ROOT_DIR  / config["paths"]["dataset_csv_raw"]
df = pd.read_csv(df_path)
df
# Out:
#                                                 img_path  height  width  \
# 0      E:/My Documents/skripsi/model_penelitian/data/...    1279   1954
# 1      E:/My Documents/skripsi/model_penelitian/data/...     560    824
# 2      E:/My Documents/skripsi/model_penelitian/data/...    1024   1024
# 3      E:/My Documents/skripsi/model_penelitian/data/...    1024   1024
# 4      E:/My Documents/skripsi/model_penelitian/data/...     256    256
# ...                                                  ...     ...    ...
# 20763  E:/My Documents/skripsi/model_penelitian/data/...    1080   1376
# 20764  E:/My Documents/skripsi/model_penelitian/data/...    1136   1632
# 20765  E:/My Documents/skripsi/model_penelitian/data/...     512    512
# 20766  E:/My Documents/skripsi/model_penelitian/data/...     512    512
# 20767  E:/My Documents/skripsi/model_penelitian/data/...     712   1016
#
#        image_size_kb      label
# 0            503.665  Pneumonia
# 1             40.560  Pneumonia
# 2            123.627     Normal
# 3            137.751     Normal
# 4             14.295     Normal
# ...              ...        ...
# 20763        160.588  Pneumonia
# 20764        127.777  Pneumonia
# 20765         48.542     Normal
# 20766         45.410     Normal
# 20767         70.175  Pneumonia
#
# [20768 rows x 5 columns]

# %%
output_dir_resized = os.path.join(ROOT_DIR, "data", "processed", "chest_xray_resized").replace(os.sep, "/")

resize_image(input_csv_path=df_path, output_dir=output_dir_resized)
# Out:
# [INFO] Starting process from: E:\My Documents\skripsi\model_penelitian\data\splits\chest_xray_raw.csv
# [INFO] Starting resizing process to size (224x224)...
# Resizing Images: 100%|██████████| 20768/20768 [17:14<00:00, 20.08img/s]
# [SUCCESS] Images successfully resized and saved at: E:\My Documents\skripsi\model_penelitian\data\processed\chest_xray_resized

# %%
data_dir_resized = ROOT_DIR / config["paths"]["processed_data"]
output_dir_resized = os.path.join(ROOT_DIR, "data", "splits").replace(os.sep, "/")
namespace_df_resized = "chest_xray_dataset"

build_image_to_csv(data_dir_resized, output_dir_resized, namespace_df_resized)
# Out:
# [INFO] Starting process from: E:\My Documents\skripsi\model_penelitian\data\processed\chest_xray_resized
# Processing Normal: 100%|██████████| 10671/10671 [06:11<00:00, 28.69img/s]
# Processing Pneumonia: 100%|██████████| 10097/10097 [05:33<00:00, 30.27img/s]
# [SUCCESS] CSV successfully saved at: E:\My Documents\skripsi\model_penelitian\data\splits\chest_xray_dataset.csv
# [INFO] Total Images: 20768
# [INFO] Class Distribution:
# label
# Normal       10671
# Pneumonia    10097
# Name: count, dtype: int64

# %%
df_path_resized = ROOT_DIR  / config["paths"]["dataset_csv"]
df_resized = pd.read_csv(df_path_resized)
df_resized.head()
# Out:
#                                             img_path  height  width  \
# 0  E:/My Documents/skripsi/model_penelitian/data/...     224    224
# 1  E:/My Documents/skripsi/model_penelitian/data/...     224    224
# 2  E:/My Documents/skripsi/model_penelitian/data/...     224    224
# 3  E:/My Documents/skripsi/model_penelitian/data/...     224    224
# 4  E:/My Documents/skripsi/model_penelitian/data/...     224    224
#
#    image_size_kb      label
# 0         18.304  Pneumonia
# 1         17.378  Pneumonia
# 2         11.873     Normal
# 3         14.458     Normal
# 4         18.549     Normal
